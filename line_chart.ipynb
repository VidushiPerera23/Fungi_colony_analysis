# %%
import matplotlib.pyplot as plt
from datetime import datetime

# Data from the document
dates = [
    '16.04.2024', '16.04.2024', '16.04.2024', '17.04.2024', '17.04.2024', '17.04.2024',
    '18.04.2024', '18.04.2024', '18.04.2024', '19.04.2024', '19.04.2024', '19.04.2024',
    '20.04.2024', '20.04.2024', '20.04.2024', '21.04.2024', '21.04.2024', '21.04.2024',
    '22.04.2024', '22.04.2024', '22.04.2024', '23.04.2024', '23.04.2024', '23.04.2024',
    '24.04.2024', '24.04.2024', '24.04.2024', '24.04.2024', '25.04.2024', '25.04.2024',
    '25.04.2024', '25.04.2024', '26.04.2024', '26.04.2024', '26.04.2024', '26.04.2024',
    '27.04.2024', '27.04.2024', '27.04.2024', '27.04.2024', '28.04.2024', '28.04.2024',
    '28.04.2024', '28.04.2024', '29.04.2024', '29.04.2024', '29.04.2024', '29.04.2024'
]

times = [
    '06.00', '14.00', '22.00', '06.00', '14.00', '22.00', '06.00', '14.00', '22.00',
    '06.00', '14.00', '22.00', '06.00', '14.00', '22.00', '06.00', '14.00', '22.00',
    '06.00', '14.00', '22.00', '06.00', '14.00', '22.00', '06.00', '12.00', '18.00',
    '00.00', '06.00', '12.00', '18.00', '00.00', '06.00', '12.00', '18.00', '00.00',
    '06.00', '12.00', '18.00', '00.00', '06.00', '12.00', '18.00', '00.00', '06.00',
    '12.00', '18.00', '00.00'
]

ambewela = [
    2.08, 1.87, 2.12, 1.87, 2.07, 1.92, 2.14, 1.99, 2.07, 2.13, 2.21, 2.26, 2.34, 3.60, 3.02,
    3.98, 3.59, 6.98, 7.71, 10.66, 12.13, 11.07, 11.52, 12.94, 12.09, 12.81, 13.18, 12.52,
    11.10, 13.71, 13.54, 13.06, 14.44, 12.90, 12.04, 12.40, 12.40, 12.44, 12.44, 10.53,
    14.32, 15.08, 14.17, 13.35, 14.17, 13.03, 15.08, 15.45
]

kotmale = [
    1.84, 1.97, 1.82, 2.51, 2.39, 1.86, 1.96, 1.95, 2.01, 2.09, 2.82, 2.46, 2.98, 2.98, 3.03,
    3.56, 3.09, 5.14, 5.51, 10.81, 15.72, 14.80, 16.44, 17.59, 17.61, 18.58, 18.79, 19.51,
    19.47, 20.91, 19.52, 19.20, 21.37, 21.37, 21.76, 11.60, 22.00, 11.60, 22.00, 21.72,
    21.99, 20.91, 21.29, 15.02, 21.95, 21.95, 17.80, 21.81
]

michico = [
    1.86, 1.86, 1.87, 1.86, 1.90, 2.32, 1.92, 2.01, 1.89, 1.98, 3.01, 2.69, 1.96, 2.32, 1.97,
    2.07, 2.07, 1.86, 3.27, 13.82, 21.08, 17.66, 22.39, 22.64, 17.59, 22.58, 22.79, 19.02,
    16.92, 23.47, 22.22, 22.29, 21.48, 23.33, 22.19, 23.61, 21.11, 23.61, 21.11, 23.67,
    23.71, 21.58, 19.20, 21.43, 20.12, 20.12, 19.05, 15.89
]

# Convert Date and Time into a single datetime object
datetimes = [datetime.strptime(f"{date} {time}", "%d.%m.%Y %H.%M") for date, time in zip(dates, times)]

# Plotting the data
plt.figure(figsize=(14, 7))
plt.plot(datetimes, ambewela, marker='o', label='Ambewela')
plt.plot(datetimes, kotmale, marker='o', label='Kotmale')
plt.plot(datetimes, michico, marker='o', label='Michico')

# Adding title and labels
plt.title('Yoghurt Brands Percentage Over Time')
plt.xlabel('Date and Time')
plt.ylabel('Percentage')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()
